# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap

# %%
df = pd.read_excel("Data for AI.xlsx")

# %%
df.head()
# Out:
#    ScheduleNo District  Age  Gender  Birth_order  Educational_status  \
# 0           1   Kannur   18       2            2                   3
# 1           2   Kannur   19       2            2                   3
# 2           3   Kannur   19       2            1                   3
# 3           4   Kannur   19       2            2                   3
# 4           5   Kannur   19       2            2                   3
#
#    Nature of course  Residential_status  Place_of_residence  Diet  ...  \
# 0                 1                   1                   2     2  ...
# 1                 1                   1                   2     2  ...
# 2                 1                   1                   2     2  ...
# 3                 1                   2                   2     2  ...
# 4                 1                   1                   2     2  ...
#
#    History CMR  Anthropometric measurment  Physical  Sitting  Dietary habit  \
# ...

# %%
df.tail()
# Out:
#       ScheduleNo District  Age  Gender  Birth_order  Educational_status  \
# 1235        1236  Wayanad   19       1            1                   2
# 1236        1237  Wayanad   19       2            1                   2
# 1237        1238  Wayanad   19       1            3                   2
# 1238        1239  Wayanad   18       1            2                   2
# 1239        1240  Wayanad   18       1            1                   2
#
#       Nature of course  Residential_status  Place_of_residence  Diet  ...  \
# 1235                 2                   1                   2     2  ...
# 1236                 3                   1                   3     2  ...
# 1237                 3                   1                   3     2  ...
# 1238                 2                   1                   3     1  ...
# 1239                 3                   2                   3     2  ...
#
#       History CMR  Anthropometric measurment  Physical  Sitting  \
# ...

# %%
df.columns
# Out:
# Index(['ScheduleNo', 'District', 'Age', 'Gender', 'Birth_order',
#        'Educational_status', 'Nature of course', 'Residential_status',
#        'Place_of_residence', 'Diet', 'SES', 'Family history', 'History CMR',
#        'Anthropometric measurment', 'Physical', 'Sitting', 'Dietary habit',
#        'Alcohol use', 'smoking', 'Substance abuse', 'sleep', 'stress'],
#       dtype='object')

# %%
df.shape
# Out:
# (1240, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ScheduleNo                 1240 non-null   int64
#  1   District                   1240 non-null   object
#  2   Age                        1240 non-null   int64
#  3   Gender                     1240 non-null   int64
#  4   Birth_order                1240 non-null   int64
#  5   Educational_status         1240 non-null   int64
#  6   Nature of course           1240 non-null   int64
#  7   Residential_status         1240 non-null   int64
#  8   Place_of_residence         1240 non-null   int64
#  9   Diet                       1240 non-null   int64
#  10  SES                        1240 non-null   int64
#  11  Family history             1240 non-null   int64
#  12  History CMR                1240 non-null   int64
# ...

# %%
df.describe()
# Out:
#         ScheduleNo          Age       Gender  Birth_order  Educational_status  \
# count  1240.000000  1240.000000  1240.000000  1240.000000         1240.000000
# mean    620.500000    18.726613     1.522581     1.734677            2.138710
# std     358.101475     0.477350     0.501304     0.802392            0.688978
# min       1.000000    17.000000     1.000000     1.000000            1.000000
# 25%     310.750000    18.000000     1.000000     1.000000            2.000000
# 50%     620.500000    19.000000     2.000000     2.000000            2.000000
# 75%     930.250000    19.000000     2.000000     2.000000            3.000000
# max    1240.000000    20.000000     3.000000     4.000000            3.000000
#
#        Nature of course  Residential_status  Place_of_residence         Diet  \
# count       1240.000000         1240.000000         1240.000000  1240.000000
# mean           1.829839            1.350806            2.279032     1.997581
# ...

# %%
df["District"].value_counts()
# Out:
# Kannur      423
# Kasargod    413
# Wayanad     404
# Name: District, dtype: int64

# %%
df['District'].replace(['Kannur','Kasargod','Wayanad'],
                        [0, 1,2], inplace=True)

# %%
df.head()
# Out:
#    ScheduleNo  District  Age  Gender  Birth_order  Educational_status  \
# 0           1         0   18       2            2                   3
# 1           2         0   19       2            2                   3
# 2           3         0   19       2            1                   3
# 3           4         0   19       2            2                   3
# 4           5         0   19       2            2                   3
#
#    Nature of course  Residential_status  Place_of_residence  Diet  ...  \
# 0                 1                   1                   2     2  ...
# 1                 1                   1                   2     2  ...
# 2                 1                   1                   2     2  ...
# 3                 1                   2                   2     2  ...
# 4                 1                   1                   2     2  ...
#
#    History CMR  Anthropometric measurment  Physical  Sitting  Dietary habit  \
# ...

# %% [markdown]
# ### Delete the irrevelant features

# %%
df.drop(["ScheduleNo",'District',"Educational_status","Nature of course","Residential_status",'Place_of_residence','SES'],axis=1,inplace = True)

# %%
df.shape
# Out:
# (1240, 15)

# %%
df.corr()
# Out:
#                                 Age    Gender  Birth_order      Diet  \
# Age                        1.000000 -0.066934     0.088620 -0.026215
# Gender                    -0.066934  1.000000     0.086137  0.031579
# Birth_order                0.088620  0.086137     1.000000 -0.043112
# Diet                      -0.026215  0.031579    -0.043112  1.000000
# Family history            -0.009671 -0.088633    -0.009970 -0.024928
# History CMR                0.044764 -0.004593     0.004871  0.014842
# Anthropometric measurment -0.009759  0.006985    -0.022056  0.013272
# Physical                   0.039119  0.116693    -0.009433  0.028225
# Sitting                    0.016391 -0.063206    -0.001866 -0.037659
# Dietary habit             -0.010794  0.041857     0.063097  0.011412
# Alcohol use                0.002439  0.043051    -0.011407 -0.002342
# smoking                    0.018848 -0.172996    -0.014956  0.025379
# Substance abuse            0.011418 -0.158897    -0.015163 -0.013635
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Birth_order', 'Diet', 'Family history', 'History CMR',
#        'Anthropometric measurment', 'Physical', 'Sitting', 'Dietary habit',
#        'Alcohol use', 'smoking', 'Substance abuse', 'sleep', 'stress'],
#       dtype='object')

# %%
df.shape
# Out:
# (1240, 15)

# %%
df['History CMR'].value_counts()
# Out:
# 0    954
# 1    248
# 2     29
# 3      8
# 4      1
# Name: History CMR, dtype: int64

# %%
plt.hist(df['History CMR'])
# Out:
# (array([954.,   0., 248.,   0.,   0.,  29.,   0.,   8.,   0.,   1.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# - Above graph show the data is an unbalanced data
# - So we need to do someother techniques

# %%
Clean_data = df.drop("History CMR",axis=1,inplace =False)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 3)
pca.fit(Clean_data)
data_pca = pca.transform(Clean_data)
data_pca = pd.DataFrame(data_pca,columns=['PC1','PC2','PC3'])
data_pca.head()
# Out:
#          PC1        PC2       PC3
# 0   6.833033  19.678884  6.514059
# 1   6.491944  18.967772 -8.526678
# 2  18.578802  18.944392 -4.269582
# 3 -13.140289  19.725792  2.922835
# 4 -17.021301  -5.245463 -5.341725

# %%
data_pca["History_CMR"]=df['History CMR']

# %%
data_pca.head()
# Out:
#          PC1        PC2       PC3  History_CMR
# 0   6.833033  19.678884  6.514059            0
# 1   6.491944  18.967772 -8.526678            0
# 2  18.578802  18.944392 -4.269582            0
# 3 -13.140289  19.725792  2.922835            0
# 4 -17.021301  -5.245463 -5.341725            0

# %%
sns.set(style = "darkgrid")

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = data_pca['PC1']
y = data_pca['PC2']
z = data_pca['PC3']
r = data_pca['History_CMR']


ax.scatter(x, y, z ,c=r)

plt.show()

# %%
pca = PCA(n_components = 2)
pca.fit(Clean_data)
data_pca = pca.transform(Clean_data)
data_pca = pd.DataFrame(data_pca,columns=['PC1','PC2'])
data_pca.head()
# Out:
#          PC1        PC2
# 0   6.833033  19.678884
# 1   6.491944  18.967772
# 2  18.578802  18.944392
# 3 -13.140289  19.725792
# 4 -17.021301  -5.245463

# %%
data_pca["History_CMR"]=df['History CMR']

# %%
data_pca.head()
# Out:
#          PC1        PC2  History_CMR
# 0   6.833033  19.678884            0
# 1   6.491944  18.967772            0
# 2  18.578802  18.944392            0
# 3 -13.140289  19.725792            0
# 4 -17.021301  -5.245463            0

# %%
sns.set(style = "darkgrid")
sns.scatterplot(data_pca,x='PC1',y='PC2',hue = 'History_CMR')
# Out:
# <Axes: xlabel='PC1', ylabel='PC2'>

# %%
explained_variance_ratio = pca.explained_variance_ratio_
pc_vs_variance = np.cumsum(pca.explained_variance_ratio_)
plt.plot(pc_vs_variance)
plt.xlabel('Number of Components')
plt.ylabel('% Explained Variance')
plt.title('PCA Explained Variance vs. Number of Components')
plt.show()

# %%
X = df.drop('History CMR',axis=1)
y = df['History CMR']

# %%
X.shape,y.shape
# Out:
# ((1240, 14), (1240,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=43)

# %%
X_test.shape,X_train.shape,y_train.shape,y_test.shape
# Out:
# ((248, 14), (992, 14), (992,), (248,))

# %% [markdown]
# ### Imbalanced Data

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %%
ros = RandomOverSampler(random_state=42)
X_train_ros, y_train_ros= ros.fit_resample(X_train, y_train)

# %%
from collections import Counter

# %%
print(sorted(Counter(y_train_ros).items()))
# Out:
# [(0, 774), (1, 774), (2, 774), (3, 774), (4, 774)]

# %%
X_train_ros.shape,y_train_ros.shape
# Out:
# ((3870, 14), (3870,))

# %%
pca = PCA(n_components = 2)
pca.fit(X_train_ros)
data_pc = pca.transform(X_train_ros)
data_pc = pd.DataFrame(data_pc,columns=['PC1','PC2'])
data_pc.head()
# Out:
#          PC1        PC2
# 0 -41.696298  -5.622563
# 1 -22.052813  -5.799597
# 2  -2.650979  20.351850
# 3  17.337730   5.243622
# 4  37.719294  -4.785096

# %%
explained_variance_ratio = pca.explained_variance_ratio_
pc_vs_variance = np.cumsum(pca.explained_variance_ratio_)
plt.plot(pc_vs_variance)
plt.xlabel('Number of Components')
plt.ylabel('% Explained Variance')
plt.title('PCA Explained Variance vs. Number of Components')
plt.show()

# %%
data_pc["History_CMR"]=df['History CMR']

# %%
data_pc.head()
# Out:
#          PC1        PC2  History_CMR
# 0 -41.696298  -5.622563          0.0
# 1 -22.052813  -5.799597          0.0
# 2  -2.650979  20.351850          0.0
# 3  17.337730   5.243622          0.0
# 4  37.719294  -4.785096          0.0

# %%
sns.set(style = "darkgrid")
sns.scatterplot(data_pc,x='PC1',y='PC2',hue = 'History_CMR')
# Out:
# <Axes: xlabel='PC1', ylabel='PC2'>

# %%
conf_matrix = confusion_matrix(y_test,y_pred)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
        
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
